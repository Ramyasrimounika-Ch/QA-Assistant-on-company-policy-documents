# %%
import os
from langchain_community.document_loaders import PyPDFLoader
from langchain_community.document_loaders import DirectoryLoader
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_groq import ChatGroq
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
loader=DirectoryLoader("data", glob = "./*.pdf", loader_cls= PyPDFLoader)

# %%
data=loader.load()

# %%
data
# Out:
# [Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-12-24T00:03:40+05:30', 'author': 'CH Mouni', 'moddate': '2025-12-24T00:03:40+05:30', 'source': 'data\\Cancellation Policy.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content="Cancellation Policy:- \nThe customer can choose to cancel an order any time before it's dispatched. The order \ncannot be canceled once it’s out for delivery. However, the customer may choose to reject it \nat the doorstep. \nThe time window for cancellation varies based on different categories and the order cannot \nbe canceled once the specified time has passed. \nIn some cases, the customer may not be allowed to cancel the order for free, post the \nspecified time and a cancellation fee will be charged. The details about the time window \nmentioned on the product page or order confirmation page will be considered final. \nIn case of any cancellation from the seller due to unforeseen circumstances, a full refund will \nbe initiated for prepaid orders. \nFlipkart reserves the right to accept the cancellation of any order. Flipkart also reserves the \nright to waive off or modify the time window or cancellation fee from time to time. \nCancellation Policy – Hyperlocal:- \nThe Orders placed by you on the Platform are non-cancellable and non-refundable via self \nserve under MINUTES delivery option owing to quick delivery times, except if \ncancellation/refund is requested via CX Agent under the following circumstances: \n• The Order could not be delivered within the estimated time that was displayed while \nplacing the order; \n• The Order has not been picked by the Delivery Partner; \n• The Seller has not accepted or has canceled the Order due to reasons not \nattributable to You. \n• Easy Doorstep Cancellation \n• Any other reason that the Platform may update from time to time \nWe reserve the right to cancel your order, in whole or in part, for reasons including product \nunavailability, unforeseen circumstances beyond our control (force majeure), suspected \nfraudulent activity, violation of our Terms of Use, or logistical constraints. In all instances of \ncancellation (by us), you will not be charged for the canceled order. Any payments you have \nalready made will be promptly refunded within 5-7 business days for any cancellations. You \ncan track the status of your refund on the Order Details page/section. \nOur return, cancellation, and refund policies may be subject to additional reasonable terms \nand conditions. These will be communicated to you periodically through the Platform's push \nnotifications or other communication methods as outlined within these Terms or as \ndetermined by the Company."),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-12-24T00:20:14+05:30', 'author': 'CH Mouni', 'moddate': '2025-12-24T00:20:14+05:30', 'source': 'data\\complaint policy.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Grievance Redressal Mechanism:- \nFlipkart is duty bound to provide fair treatment to our Consumer and Consumer grievances. \nWhat does "Grievance" mean? \nGrievance means any issue related to the product/service which has been availed by the \nconsumer from the Flipkart Platform and consumer is seeking resolution for the same. \nIn case of any query or complaint the Consumer can approach us and reach out to us \nthrough ‘Contact us’ and ‘Help Centre’ tab available on this page. \nJourney: \n1. Click on ‘Contact Us’ or ‘Help Centre’ tab \n2. It will open to Flipkart Help Center | 24x7 Customer Care Support \n3. Choose from Type of Issue / Help Topics \n4. Submit \nIf your query / complaint not resolved needs to be escalated : As per the applicable laws, \nFlipkart has appointed a “Grievance Officer” to address your grievances. \nHere are the details for Grievance officer: \nMr. Shremanth M \nDesignation: Senior Manager \nFlipkart Internet Pvt Ltd Block B (Begonia), \n8th Floor Embassy Tech Village, \nOuter Ring Road, Devarabeesanahalli Village, \nVarthur Hobli, Bengaluru East Taluk, \nBengaluru District, Karnataka : 560103, India \nContact no. : 044-45614700 \n• Our ‘Grievance Redressal Mechanism’ is as follows: \no Upon the receipt of a Consumer Grievance on the channels specified above. \n▪ The Consumer shall receive an acknowledgment for its grievance \nwithin 48 (Forty-Eight) hours through email OR phone call or SMS, and \n▪ The Consumer shall receive a system generated “Unique ID” to track \nthe grievance status'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-12-24T00
chase on Flipkart. The prices listed for all \nthe items are final and all-inclusive. The price you see on the product page is exactly what \nyou pay. \nDelivery charges may be extra depending on the seller policy. Please check individual seller \nfor the same. In case of seller WS Retail, the ₹50 delivery charge is waived off on orders \nworth ₹500 and over. \nWhat is Cash on Delivery? \nIf you are not comfortable making an online payment on Flipkart.com, you can opt for the \nCash on Delivery (C-o-D) payment method instead. With C-o-D you can pay in cash at the \ntime of actual delivery of the product at your doorstep, without requiring you to make any \nadvance payment online. \nThe maximum order value for a Cash on Delivery (C-o-D) payment is ₹50,000. It is strictly a \ncash-only payment method. Gift Cards or store credit cannot be used for C-o-D orders. \nForeign currency cannot be used to make a C-o-D payment. Only Indian Rupees accepted. \nHow do I pay using a credit/debit card? \nWe accept payments made by credit/debit cards issued in India and 21 other countries. \nCredit cards \nWe accept payments made using Visa, MasterCard and American Express credit cards. \nTo pay using your credit card at checkout, you will need your card number, expiry date, \nthree-digit CVV number (found on the backside of your card). After entering these details, \nyou will be redirected to the bank's page for entering the online 3D Secure password. \nDebit cards \nWe accept payments made using Visa, MasterCard and Maestro debit cards."),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-12-24T00:12:31+05:30', 'author': 'CH Mouni', 'moddate': '2025-12-24T00:12:31+05:30', 'source': 'data\\Payments policy.pdf', 'total_pages': 7, 'page': 1, 'page_label': '2'}, page_content='To pay using your debit card at checkout, you will need your card number, expiry date \n(optional for Maestro cards), three-digit CVV number (optional for Maestro cards). You will \nthen be redirected to your bank\'s secure page for entering your online password (issued by \nyour bank) to complete the payment. \nInternationally issued credit/debit cards cannot be used for Flyte, Wallet and eGV \npayments/top-ups. \nIs it safe to use my credit/debit card on Flipkart? \nYour online transaction on Flipkart is secure with the highest levels of transaction security \ncurrently available on the Internet. Flipkart uses 256-bit encryption technology to protect \nyour card information while securely transmitting it to the respective banks for payment \nprocessing. \nAll credit card and debit card payments on Flipkart are processed through secure and trusted \npayment gateways managed by leading banks. Banks now use the 3D Secure password \nservice for online transactions, providing an additional layer of security through identity \nverification. \nWhat steps does Flipkart take to prevent card fraud? \nFlipkart realizes the importance of a strong fraud detection and resolution capability. We and \nour online payments partners monitor transactions continuously for suspicious activity and \nflag potentially fraudulent transactions for manual verification by our team. \nIn the rarest of rare cases, when our team is unable to rule out the possibility of fraud \ncategorically, the transaction is kept on hold, and the customer is requested to provide \nidentity documents. The ID documents help us ensure that the purchases were indeed made \nby a genuine card holder. We apologise for any inconvenience that may be caused to \ncustomers and request them to bear with us in the larger interest of ensuring a safe and \nsecure environment for online transactions. \nWhat is a 3D Secure password? \nThe 3D Secure password is implemented by VISA and MasterCard in partnership with card \nissuing banks under the "Verified by VISA" and "Mastercard SecureCode" services, \nrespectively. \nThe 3D Secure password adds an additional layer of security through identity verification for \nyour online credit/debit card transactions. This password, which is created by you, is known \nonly to you. This ensures that only you can use your card for online purchases. \nHow can I get the 3D Secure password for my credit/debit card?'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-12-24T00:12:31+05:30', 'author': 'CH Mouni', 'moddate': '2025-12-24T00:12:31+05:30', 'source': 'data\\Payments policy.pdf', 'total_pages': 7, 'page': 2, 'page_label': '
pdf', 'total_pages': 7, 'page': 5, 'page_label': '6'}, page_content="Banks Supports 18 & 24 \nmonths tenure \nMinimum order value to avail 18 & 24 \nmonths EMI options \nHDFC Yes ₹ 10,000 \nCiti Yes ₹ 10,000 \nICICI Yes ₹ 10,000 \nKotak Yes ₹ 4,000 \nAxis Yes ₹ 4,000 \nIndusInd Yes ₹ 4,000 \nSBI No NA \nStandard \nChartered Yes ₹ 4,000 \nHSBC No NA \nThere is NO processing fee charged for availing Flipkart's EMI payment option. On return or \nexchange, interest charged by the bank till that time will not be refunded by Flipkart. \nYou may check with the respective bank/issuer on how a cancellation, refund or pre-closure \ncould affect the EMI terms, and what interest charges would be levied on you for the same. \nExample and Calculations:- \nThe table below shows a representative rendering of EMI plans for a Rs 20,000 purchase on \nFlipkart paid using the EMI payment plan"),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-12-24T00:12:31+05:30', 'author': 'CH Mouni', 'moddate': '2025-12-24T00:12:31+05:30', 'source': 'data\\Payments policy.pdf', 'total_pages': 7, 'page': 6, 'page_label': '7'}, page_content="Tenure \n(months) \nLoan \namount \nMonthly \ninstallment \nBank \ninterest \nrate \nTotal effective \nprice you pay \nInterest paid \nto Bank \n3 Rs 20,000 Rs 6,800.44 12.00% Rs. 20,401.33 Rs. 401.33 \n6 Rs 20,000 Rs 3,450.97 12.00% Rs 20,705.80 Rs. 705.80 \n9 Rs 20,000 Rs 2,344.32 13.00% Rs 21,098.89 Rs. 1,098.89 \n12 Rs 20,000 Rs 1,786.35 13.00% Rs 21,436.15 Rs. 1,436.15 \nHow do I make a payment using Flipkart's credit card EMI option? \nOnce you've added the desired items to your Flipkart shopping cart, proceed with your order \nas usual by entering your address. When you're prompted to choose a payment mode for \nyour order, select 'EMI' & follow these simple steps: \n1. Choose your credit-card issuing bank you wish to pay from \n2. Select the EMI plan of your preference \n3. Enter your credit card details \n4. Click 'Save and Pay' \nPlease note that the full amount will be charged on your card the day of the transaction."),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-12-24T00:07:59+05:30', 'author': 'CH Mouni', 'moddate': '2025-12-24T00:07:59+05:30', 'source': 'data\\privacy policy.pdf', 'total_pages': 8, 'page': 0, 'page_label': '1'}, page_content="PRIVACY POLICY:- \nDisclaimer: In case of any discrepancy or difference, the English version will take precedence \nover the translation \nWe value the trust you place in us and recognize the importance of secure transactions and \ninformation privacy. This Privacy Policy describes how Flipkart Internet Private Limited and its \naffiliates, group companies and related parties (collectively “Flipkart, we, our, us”) collect, \nuse, share or otherwise process your personal data through Flipkart \nwebsite www.flipkart.com, its mobile application, and m-site (hereinafter referred to as the \n“Platform”). \nWhile you can browse sections of the Platform without the need of sharing any information \nwith us, however, please note we do not offer any product or service under this Platform \noutside India and your personal data will primarily be stored and processed in India. By \nvisiting this Platform, providing your information or availing out product/service, you \nexpressly agree to be bound by the terms and conditions of this Privacy Policy, the Terms of \nUse and the applicable service/product terms and conditions, and agree to be governed by \nthe laws of India including but not limited to the laws applicable to data protection and \nprivacy. If you do not agree please do not use or access our Platform. \nCollection of Your Information:- \nWhen you use our Platform, we collect and store your information which is provided by you \nfrom time to time. Once you give us your personal data, you are not anonymous to us. \nWhere possible, we indicate which fields are required and which fields are optional. You \nalways have the option to not provide data by choosing not to use a particular service, \nproduct or feature on the Platform. \nWe collect and analyse your personal data relating to your buying behavior, browsing \npatterns, preferences, and other information that you choose to provide while interacting \nwith our Platform. We use this information to do internal research on our users' \ndemographics, interests, usage trends, and behavior to better understand your needs and \nprovide you with an enhanced user experience, protect and serve our users. Additionally, this \ninformation may also be compiled and analyzed on an aggregated basis. This information \nmay include the
05:30', 'author': 'CH Mouni', 'moddate': '2025-12-23T23:54:33+05:30', 'source': 'data\\Shipping policy.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content="Shipping: \nWhy does the delivery date not correspond to the delivery timeline of X-Y business days? \nIt is possible that the Seller or our delivery partners have a holiday between the day you \nplaced your order and the date of delivery, which is based on the timelines shown on the \nproduct page. In this case, we add a day to the estimated date. Some delivery partners and \nSellers do not work on Sundays and this is factored in to the delivery dates. \nWhat is the estimated delivery time? \nSellers generally procure and ship the items within the time specified on the product page. \nBusiness days exclude public holidays and Sundays. \nEstimated delivery time depends on the following factors: \n• The Seller offering the product \n• Product's availability with the Seller \n• The destination to which you want the order shipped to and location of the Seller. \nWhy does the estimated delivery time vary for each seller? \nYou have probably noticed varying estimated delivery times for sellers of the product you are \ninterested in. Delivery times are influenced by product availability, geographic location of the \nSeller, your shipping destination and the delivery partner's time-to-deliver in your location. \nPlease enter your default pin code on the product page (you don't have to enter it every \nsingle time) to know more accurate delivery times on the product page itself. \nSeller does not/cannot ship to my area. Why? \nPlease enter your pincode on the product page (you don't have to enter it every single time) \nto know whether the product can be delivered to your location. \nIf you haven't provided your pincode until the checkout stage, the pincode in your shipping \naddress will be used to check for serviceability. \nWhether your location can be serviced or not depends on \n• Whether the Seller ships to your location \n• Legal restrictions, if any, in shipping particular products to your location \n• The availability of reliable delivery partners in your location \nAt times Sellers prefer not to ship to certain locations. This is entirely at their discretion. \nWhy is the CoD option not offered in my location?"),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-12-23T23:54:33+05:30', 'author': 'CH Mouni', 'moddate': '2025-12-23T23:54:33+05:30', 'source': 'data\\Shipping policy.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='Availability of CoD depends on the ability of our delivery partner servicing your location to \naccept cash as payment at the time of delivery. \nOur delivery partners have limits on the cash amount payable on delivery depending on the \ndestination and your order value might have exceeded this limit. Please enter your pin code \non the product page to check if CoD is available in your location. \nI need to return an item, how do I arrange for a pick-up? \nReturns are easy. Contact Us to initiate a return. You will receive a call explaining the \nprocess, once you have initiated a return. \nWherever possible Ekart Logistics will facilitate the pick-up of the item. In case, the pick-up \ncannot be arranged through Ekart, you can return the item through a third-party delivery \nservice. Return fees are borne by the Seller. \nI did not receive my order but got a delivery confirmation SMS/Email. \nIn case the product was not delivered and you received a delivery confirmation email/SMS, \nreport the issue within 7 days from the date of delivery confirmation for the seller to \ninvestigate. \nWhat do the different tags like "In Stock", "Available" mean? \n\'In Stock\':- \nFor items listed as "In Stock", Sellers will mention the delivery time based on your location \npincode (usually 2-3 business days, 4-5 business days or 4-6 business days in areas where \nstandard delivery service is available). For other areas, orders will be sent by Registered Post \nthrough the Indian Postal Service which may take 1-2 weeks depending on the location. \n\'Available\':- \nThe Seller might not have the item in stock but can procure it when an order is placed for \nthe item. The delivery time will depend on the estimated procurement time and the \nestimated shipping time to your location. \n\'Preorder\' or \'Forthcoming\':- \nSuch items are expected to be released soon and can be pre-booked for you. The item will \nbe shipped to you on the day of it\'s official release launch and will reach you in 2 to 6 \nbusiness days. The Preorder duration varies from item to item. Once known, release time \nand date is mentioned. (Eg. 5th May, August 3rd week) \n\'Out of Stock\':- \nCurrently, the item is not available for sale. Use the \'Notify Me\' feature to know once it is \navailable for purchase.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-12-23T23:54:33+05:30', 'author': 'CH Mouni', 'moddate': '2025-12-23T23:54:33+05:30', 'source': 'data\\Shipping policy.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content="'Imported':- \nSometimes, items have to be sourced by Sellers from outside India. These items are \nmentioned as 'Imported' on the product page and can take at least 10 days or more to be \ndelivered to you. \n'Back In Stock Soon':- \nThe item is popular and is sold out. You can however 'book' an order for the product and it \nwill be shipped according to the timelines mentioned by the Seller. \n'Temporarily Unavailable':- \nThe product is currently out of stock and is not available for purchase. The product could be \nin stock soon. Use the 'Notify Me' feature to know when it is available for purchase. \n'Permanently Discontinued':- \nThis product is no longer available because it is obsolete and/or its production has been \ndiscontinued. \n'Out of Print':- \nThis product is not available because it is no longer being published and has been \npermanently discontinued. \nDoes Flipkart deliver internationally? \nAs of now, Flipkart doesn't deliver items internationally. \nYou will be able to make your purchases on our site from anywhere in the world with \ncredit/debit cards issued in India and 21 other countries, but please ensure the delivery \naddress is in India.")]

# %%
import re

def clean_pdf_text(text: str) -> str:
    #Removing page numbers like "Page 1", "Page 2 of 5"
    text = re.sub(r'Page\s+\d+(\s+of\s+\d+)?', '', text, flags=re.IGNORECASE)

    #Removing repeated headers/footers
    text = re.sub(r'(Refund Policy|Cancellation Policy|Shipping Policy)', 
                  lambda m: m.group(0), text)

    #Removing extra newlines
    text = re.sub(r'\n{2,}', '\n', text)

    text = re.sub(r'\s+', ' ', text)

    return text.strip()

# %%
for doc in data:
    doc.page_content = clean_pdf_text(doc.page_content)

# %%
data[0].page_content
# Out:
# "Cancellation Policy:- The customer can choose to cancel an order any time before it's dispatched. The order cannot be canceled once it’s out for delivery. However, the customer may choose to reject it at the doorstep. The time window for cancellation varies based on different categories and the order cannot be canceled once the specified time has passed. In some cases, the customer may not be allowed to cancel the order for free, post the specified time and a cancellation fee will be charged. The details about the time window mentioned on the product page or order confirmation page will be considered final. In case of any cancellation from the seller due to unforeseen circumstances, a full refund will be initiated for prepaid orders. Flipkart reserves the right to accept the cancellation of any order. Flipkart also reserves the right to waive off or modify the time window or cancellation fee from time to time. Cancellation Policy – Hyperlocal:- The Orders placed by you on the Platform are non-cancellable and non-refundable via self serve under MINUTES delivery option owing to quick delivery times, except if cancellation/refund is requested via CX Agent under the following circumstances: • The Order could not be delivered within the estimated time that was displayed while placing the order; • The Order has not been picked by the Delivery Partner; • The Seller has not accepted or has canceled the Order due to reasons not attributable to You. • Easy Doorstep Cancellation • Any other reason that the Platform may update from time to time We reserve the right to cancel your order, in whole or in part, for reasons including product unavailability, unforeseen circumstances beyond our control (force majeure), suspected fraudulent activity, violation of our Terms of Use, or logistical constraints. In all instances of cancellation (by us), you will not be charged for the canceled order. Any payments you have already made will be promptly refunded within 5-7 business days for any cancellations. You can track the status of your refund on the Order Details page/section. Our return, cancellation, and refund policies may be subject to additional reasonable terms and conditions. These will be communicated to you periodically through the Platform's push notifications or other communication methods as outlined within these Terms or as determined by the Company."

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size=800, chunk_overlap=150)
splitted_data = splitter.split_documents(data)

# %% [markdown]
# I choose a chunk size of 800 characters because policy rules often extend to multiple sentences if we use smaller chunks (like 200–300) can seperate a policy rule into half, separating the main rule from its exceptions, which can lead to incomplete or misleading answers. So, I choose 800 as chuck size,800 characters usually capture a complete policy rule and if we want we can use 1000 also. Policy documents are usually written in full paragraphs, and those paragraphs often explains one complete rule. With this large chuck size, most chunks naturally contain a whole idea instead of cutting it into half.
#
# If the chunks is too small then, important details like exceptions or conditions could get separated, which would confuse the system during retrieval. If they were too big, the model might give extra, unrelated information. The chunk_overlap makes sure that nothing important information gets lost between chunks.
#
# Overall, this chunk size just felt like the right value to use because it keeps the policy text together in a way that makes sense,and because no important information will get seperated,which leads to accurate and, more reliable answers.

# %%
splitted_data[0]
# Out:
# Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-12-24T00:03:40+05:30', 'author': 'CH Mouni', 'moddate': '2025-12-24T00:03:40+05:30', 'source': 'data\\Cancellation Policy.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content="Cancellation Policy:- The customer can choose to cancel an order any time before it's dispatched. The order cannot be canceled once it’s out for delivery. However, the customer may choose to reject it at the doorstep. The time window for cancellation varies based on different categories and the order cannot be canceled once the specified time has passed. In some cases, the customer may not be allowed to cancel the order for free, post the specified time and a cancellation fee will be charged. The details about the time window mentioned on the product page or order confirmation page will be considered final. In case of any cancellation from the seller due to unforeseen circumstances, a full refund will be initiated for prepaid orders. Flipkart reserves the right to accept the cancellation")

# %%
splitted_data[0].page_content
# Out:
# "Cancellation Policy:- The customer can choose to cancel an order any time before it's dispatched. The order cannot be canceled once it’s out for delivery. However, the customer may choose to reject it at the doorstep. The time window for cancellation varies based on different categories and the order cannot be canceled once the specified time has passed. In some cases, the customer may not be allowed to cancel the order for free, post the specified time and a cancellation fee will be charged. The details about the time window mentioned on the product page or order confirmation page will be considered final. In case of any cancellation from the seller due to unforeseen circumstances, a full refund will be initiated for prepaid orders. Flipkart reserves the right to accept the cancellation"

# %%
splitted_data[1].page_content
# Out:
# 'seller due to unforeseen circumstances, a full refund will be initiated for prepaid orders. Flipkart reserves the right to accept the cancellation of any order. Flipkart also reserves the right to waive off or modify the time window or cancellation fee from time to time. Cancellation Policy – Hyperlocal:- The Orders placed by you on the Platform are non-cancellable and non-refundable via self serve under MINUTES delivery option owing to quick delivery times, except if cancellation/refund is requested via CX Agent under the following circumstances: • The Order could not be delivered within the estimated time that was displayed while placing the order; • The Order has not been picked by the Delivery Partner; • The Seller has not accepted or has canceled the Order due to reasons not'

# %%
embedding = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# %%
db = FAISS.from_documents(splitted_data, embedding)

# %%
import pickle
file_path="vector_index.pkl"
with open(file_path, "wb") as f:
    pickle.dump(db, f)

# %%
if os.path.exists(file_path):
    with open(file_path,"rb") as f:
        vectori=pickle.load(f)

# %%
query="Until what stage of an order can a customer cancel it on Flipkart?"
result=vectori.similarity_search(query)
result
# Out:
# [Document(id='beb8b02b-1da4-484b-9cda-0eb13aca5ddf', metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-12-24T00:03:40+05:30', 'author': 'CH Mouni', 'moddate': '2025-12-24T00:03:40+05:30', 'source': 'data\\Cancellation Policy.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content="Cancellation Policy:- The customer can choose to cancel an order any time before it's dispatched. The order cannot be canceled once it’s out for delivery. However, the customer may choose to reject it at the doorstep. The time window for cancellation varies based on different categories and the order cannot be canceled once the specified time has passed. In some cases, the customer may not be allowed to cancel the order for free, post the specified time and a cancellation fee will be charged. The details about the time window mentioned on the product page or order confirmation page will be considered final. In case of any cancellation from the seller due to unforeseen circumstances, a full refund will be initiated for prepaid orders. Flipkart reserves the right to accept the cancellation"),
#  Document(id='487b324a-5108-480f-9b31-2d6aaec22c4d', metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-12-24T00:03:40+05:30', 'author': 'CH Mouni', 'moddate': '2025-12-24T00:03:40+05:30', 'source': 'data\\Cancellation Policy.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='seller due to unforeseen circumstances, a full refund will be initiated for prepaid orders. Flipkart reserves the right to accept the cancellation of any order. Flipkart also reserves the right to waive off or modify the time window or cancellation fee from time to time. Cancellation Policy – Hyperlocal:- The Orders placed by you on the Platform are non-cancellable and non-refundable via self serve under MINUTES delivery option owing to quick delivery times, except if cancellation/refund is requested via CX Agent under the following circumstances: • The Order could not be delivered within the estimated time that was displayed while placing the order; • The Order has not been picked by the Delivery Partner; • The Seller has not accepted or has canceled the Order due to reasons not'),
#  Document(id='cc9273c5-dc92-453d-9afd-1c7eb31a1b52', metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-12-24T00:09:47+05:30', 'author': 'CH Mouni', 'moddate': '2025-12-24T00:09:47+05:30', 'source': 'data\\Flipkart Terms of Use.pdf', 'total_pages': 6, 'page': 2, 'page_label': '3'}, page_content="and Sellers. All discounts, offers (including exchange offers) are by the Seller/Brand and not by Flipkart. 2. Placement of order by a Buyer with Seller on the Platform is an offer to buy the product(s) in by the Buyer to the Seller and it shall not be construed as Seller's acceptance of Buyer's offer to buy the product(s) ordered. The Seller retains the right to cancel any such order placed by the Buyer, at its sole discretion and the Buyer shall be intimated of the same by way of an email/SMS. Any transaction price paid by Buyer in case of such cancellation by Seller, shall be refunded to the Buyer. Further, the Seller may cancel an order wherein the quantities exceed the typical individual consumption. This applies both to the number of products ordered within a single order and the"),
#  Document(id='fd012cfc-574f-4296-ad5f-ffcb74bdd0b2', metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-12-24T00:30:01+05:30', 'author': 'CH Mouni', 'moddate': '2025-12-24T00:30:01+05:30', 'source': 'data\\seller policy.pdf', 'total_pages': 8, 'page': 2, 'page_label': '3'}, page_content='on your behalf in respect of products sold by you. This authority shall include performing incidental acts which are specifically required to be carried out and perform the specific authority granted herein. You also provide your consent to populate your details, including, but not limited to, the Seller Address, provided by you at the time of registration on the Seller Portal (seller.flipkart.com), on the products listed by you on the platform. Seller Account Deactivation:- As per our policy, if a Seller requests for a closure of the account, the account will be put on hold for a period of 90 days to ensure smooth closure of transactions which have been made prior to his closure request and this will be available to the said Seller for downloading payment and taxation reports, if')]

# %%
result[0].page_content
# Out:
# "Cancellation Policy:- The customer can choose to cancel an order any time before it's dispatched. The order cannot be canceled once it’s out for delivery. However, the customer may choose to reject it at the doorstep. The time window for cancellation varies based on different categories and the order cannot be canceled once the specified time has passed. In some cases, the customer may not be allowed to cancel the order for free, post the specified time and a cancellation fee will be charged. The details about the time window mentioned on the product page or order confirmation page will be considered final. In case of any cancellation from the seller due to unforeseen circumstances, a full refund will be initiated for prepaid orders. Flipkart reserves the right to accept the cancellation"

# %%
query="What option does a customer have if an order cannot be cancelled once it is out for delivery?"
result2=vectori.similarity_search(query,k=2)
result2
# Out:
# [Document(id='487b324a-5108-480f-9b31-2d6aaec22c4d', metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-12-24T00:03:40+05:30', 'author': 'CH Mouni', 'moddate': '2025-12-24T00:03:40+05:30', 'source': 'data\\Cancellation Policy.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='seller due to unforeseen circumstances, a full refund will be initiated for prepaid orders. Flipkart reserves the right to accept the cancellation of any order. Flipkart also reserves the right to waive off or modify the time window or cancellation fee from time to time. Cancellation Policy – Hyperlocal:- The Orders placed by you on the Platform are non-cancellable and non-refundable via self serve under MINUTES delivery option owing to quick delivery times, except if cancellation/refund is requested via CX Agent under the following circumstances: • The Order could not be delivered within the estimated time that was displayed while placing the order; • The Order has not been picked by the Delivery Partner; • The Seller has not accepted or has canceled the Order due to reasons not'),
#  Document(id='beb8b02b-1da4-484b-9cda-0eb13aca5ddf', metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-12-24T00:03:40+05:30', 'author': 'CH Mouni', 'moddate': '2025-12-24T00:03:40+05:30', 'source': 'data\\Cancellation Policy.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content="Cancellation Policy:- The customer can choose to cancel an order any time before it's dispatched. The order cannot be canceled once it’s out for delivery. However, the customer may choose to reject it at the doorstep. The time window for cancellation varies based on different categories and the order cannot be canceled once the specified time has passed. In some cases, the customer may not be allowed to cancel the order for free, post the specified time and a cancellation fee will be charged. The details about the time window mentioned on the product page or order confirmation page will be considered final. In case of any cancellation from the seller due to unforeseen circumstances, a full refund will be initiated for prepaid orders. Flipkart reserves the right to accept the cancellation")]

# %%
content=""
for doc in result:
    content+=doc.page_content
    content+='.'

# %%
content
# Out:
# "Cancellation Policy:- The customer can choose to cancel an order any time before it's dispatched. The order cannot be canceled once it’s out for delivery. However, the customer may choose to reject it at the doorstep. The time window for cancellation varies based on different categories and the order cannot be canceled once the specified time has passed. In some cases, the customer may not be allowed to cancel the order for free, post the specified time and a cancellation fee will be charged. The details about the time window mentioned on the product page or order confirmation page will be considered final. In case of any cancellation from the seller due to unforeseen circumstances, a full refund will be initiated for prepaid orders. Flipkart reserves the right to accept the cancellation.seller due to unforeseen circumstances, a full refund will be initiated for prepaid orders. Flipkart reserves the right to accept the cancellation of any order. Flipkart also reserves the right to waive off or modify the time window or cancellation fee from time to time. Cancellation Policy – Hyperlocal:- The Orders placed by you on the Platform are non-cancellable and non-refundable via self serve under MINUTES delivery option owing to quick delivery times, except if cancellation/refund is requested via CX Agent under the following circumstances: • The Order could not be delivered within the estimated time that was displayed while placing the order; • The Order has not been picked by the Delivery Partner; • The Seller has not accepted or has canceled the Order due to reasons not.and Sellers. All discounts, offers (including exchange offers) are by the Seller/Brand and not by Flipkart. 2. Placement of order by a Buyer with Seller on the Platform is an offer to buy the product(s) in by the Buyer to the Seller and it shall not be construed as Seller's acceptance of Buyer's offer to buy the product(s) ordered. The Seller retains the right to cancel any such order placed by the Buyer, at its sole discretion and the Buyer shall be intimated of the same by way of an email/SMS. Any transaction price paid by Buyer in case of such cancellation by Seller, shall be refunded to the Buyer. Further, the Seller may cancel an order wherein the quantities exceed the typical individual consumption. This applies both to the number of products ordered within a single order and the.on your behalf in respect of products sold by you. This authority shall include performing incidental acts which are specifically required to be carried out and perform the specific authority granted herein. You also provide your consent to populate your details, including, but not limited to, the Seller Address, provided by you at the time of registration on the Seller Portal (seller.flipkart.com), on the products listed by you on the platform. Seller Account Deactivation:- As per our policy, if a Seller requests for a closure of the account, the account will be put on hold for a period of 90 days to ensure smooth closure of transactions which have been made prior to his closure request and this will be available to the said Seller for downloading payment and taxation reports, if."

# %%
llm=ChatGroq(
    model="llama-3.1-8b-instant"
)

# %%
from langchain_core.prompts import ChatPromptTemplate

initial_prompt = ChatPromptTemplate.from_template("""
you are an expert in answering questions about company policies.
Answer the following question based only on the provided context.
<context>
{context}
</context>
Question: {input}
""")

# %%
chain =initial_prompt|llm

# %%
query="Until what stage of an order can a customer cancel it on Flipkart?"
ans = chain.invoke({"context": content,"input": query})

# %%
ans
# Out:
# AIMessage(content="According to the Cancellation Policy mentioned in the context, a customer can choose to cancel an order any time before it's dispatched.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 27, 'prompt_tokens': 711, 'total_tokens': 738, 'completion_time': 0.032044664, 'completion_tokens_details': None, 'prompt_time': 0.064692523, 'prompt_tokens_details': None, 'queue_time': 0.068452247, 'total_time': 0.096737187}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_ff2b098aaf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b4f4e-6a84-7a32-a04b-1aef86b06b74-0', usage_metadata={'input_tokens': 711, 'output_tokens': 27, 'total_tokens': 738})

# %%
ans.content
# Out:
# "According to the Cancellation Policy mentioned in the context, a customer can choose to cancel an order any time before it's dispatched."

# %%
improved_prompt=ChatPromptTemplate.from_template("""
You are an excellent policy question-answering assistant who will answers the user questions effiently and accurately and also you are an assistant who follow the given rules.

Rules:
1. Answer the given question only using the information provided in the context.
2. Do NOT use any prior knowledge or make assumptions on your own.
3. If the answer is not explicitly stated or is unclear, respond with:
   "I could not find this information in the provided policy documents."
4. Keep your response concise, factual, and easy to understand.

Context:
{context}

Question:
{input}

Answer Format:
- **Answer**: <clear answer based on context>
- **Source**: <name of the policy document>
""")

# %% [markdown]
# The initial prompt simply telling the model to answer questions using the provided context.In this prompt,I did not restrict the model from using outside knowledge or guessing the answer when the answer is unclear. It also does not specify how the final answer should be displayed.And also it doesn't include how the model should response when the answer is missing.
#
# In the improved prompt,I added explicit rules that clearly tell the model to rely only on the retrieved context and not make any assumptions. I also included a structured response for cases where the information is missing or unclear, which helps prevent hallucinated answers. Additionally, the improved prompt enforces a structured output format, making the responses easier to read, more consistent, and easier to understand.
#
# Overall, these changes make the assistant more reliable, and aligned with the goal of accurate policy-based question answering.

# %%
chain2=improved_prompt|llm

# %%
ans2=chain2.invoke({"context": content,"input": query})

# %%
ans2
# Out:
# AIMessage(content="**Answer**: The customer can cancel an order any time before it's dispatched.\n**Source**: Cancellation Policy", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 806, 'total_tokens': 829, 'completion_time': 0.033752352, 'completion_tokens_details': None, 'prompt_time': 0.045801656, 'prompt_tokens_details': None, 'queue_time': 0.050376913, 'total_time': 0.079554008}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_1151d4f23c', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b4f56-0bdb-7a23-91e1-ef7d8572b0be-0', usage_metadata={'input_tokens': 806, 'output_tokens': 23, 'total_tokens': 829})

# %%
print(ans2.content)
# Out:
# **Answer**: The customer can cancel an order any time before it's dispatched.
# **Source**: Cancellation Policy

# %% [markdown]
# # 4.EVALUATION

# %%
def content_retrieval(query,k=4):
    result=vectori.similarity_search(query,k=2)
    content=""
    for doc in result:
        content+=doc.page_content
        content+='.'
    return content

# %% [markdown]
# Answerable Questions

# %%
query1="Why does the cancellation time window vary across products?"
ans1 = chain2.invoke({"context":content_retrieval(query1),"input": query1})
print(ans1.content)
# Out:
# - **Answer**: The cancellation time window varies across products based on different categories.
# - **Source**: Cancellation Policy

# %%
query2="What is the maximum order value allowed for Cash on Delivery (COD)?"
ans2 = chain2.invoke({"context":content_retrieval(query2),"input": query2})
print(ans2.content)
# Out:
# **Answer**: ₹50,000
# **Source**: The policy document explaining the Cash on Delivery (C-o-D) payment method.

# %%
query3="Does Flipkart deliver items internationally?"
ans3 = chain2.invoke({"context":content_retrieval(query3,2),"input": query3})
print(ans3.content)
# Out:
# - **Answer**: As of now, Flipkart doesn't deliver items internationally.
# - **Source**: Flipkart policy documents

# %% [markdown]
# Partially answerable

# %%
query4="How long does Flipkart take to resolve customer complaints?"
ans4 = chain2.invoke({"context":content_retrieval(query4,3),"input": query4})
print(ans4.content)
# Out:
# **Answer**: Flipkart is duty bound to provide fair treatment to our Consumer and Consumer grievances. However, it does not explicitly state the timeframe required to resolve customer complaints.
# **Source**: Flipkart's Grievance Redressal Mechanism policy document

# %% [markdown]
# Same question with different prompt

# %%
query4="How long does Flipkart take to resolve customer complaints?"
ans4 = chain.invoke({"context":content_retrieval(query4,3),"input": query4})
print(ans4.content)
# Out:
# As per the information provided in the context, Flipkart's Grievance Redressal Mechanism has the following timeline for resolving customer complaints:
#
# 1. Upon receiving a Consumer Grievance, the Consumer shall receive an acknowledgment within 48 (Forty-Eight) hours through email, phone call, or SMS.
# However, the context does not explicitly state the time frame for completely resolving the issue.

# %%
query5="Are cancellation fees always charged when canceling an order?"
ans5 = chain2.invoke({"context":content_retrieval(query5,5),"input": query5})
print(ans5.content)
# Out:
# - **Answer**: No, cancellation fees are not always charged when canceling an order. In some cases, customers may not be allowed to cancel the order for free, and a cancellation fee will be charged.
# - **Source**: Our Cancellation Policy

# %% [markdown]
# Same question with different prompt

# %%
query5="Are cancellation fees always charged when canceling an order?"
ans5 = chain.invoke({"context":content_retrieval(query5,5),"input": query5})
print(ans5.content)
# Out:
# Based on the provided context, the answer is no. Cancellation fees are not always charged when canceling an order. According to the context, the customer may not be allowed to cancel the order for free after a specified time, but a cancellation fee will be charged. However, it does not explicitly state that a cancellation fee will always be charged. In some cases, like when the seller cancels the order due to unforeseen circumstances, a full refund will be initiated for prepaid orders, with no mention of any cancellation fee.

# %% [markdown]
# UnAnswerable Questions

# %%
query6="What happens if an international shipment is lost in transit?"
ans6 = chain2.invoke({"context":content_retrieval(query6,1),"input": query6})
print(ans6.content)
# Out:
# **Answer**: I could not find this information in the provided policy documents.
# **Source**: Product Availability and Delivery Section

# %% [markdown]
# same question with different prompt

# %%
query6="What happens if an international shipment is lost in transit?"
ans6 = chain.invoke({"context":content_retrieval(query6,1),"input": query6})
print(ans6.content)
# Out:
# Unfortunately, the provided context does not specifically address what happens if an international shipment is lost in transit. The context does mention that 'Imported' items can take at least 10 days or more to be delivered, but it does not provide information on what happens if the shipment is lost during transit.

# %%
query7="What happens if a payment fails after money is debited from the bank?"
ans7=chain2.invoke({"context":content_retrieval(query7,1),"input": query6})
print(ans7.content)
# Out:
# **Answer**: I could not find this information in the provided policy documents.
# **Source**: Policy Document

# %% [markdown]
# # 5.Edge Case Handling

# %% [markdown]
# Case 1: No Relevant Documents Found

# %%
question="Is there a paid express delivery guarantee with compensation?"
ans=chain2.invoke({"context":content_retrieval(question,1),"input": question})
print(ans.content)
# Out:
# **Answer**: No, there is no paid express delivery guarantee with compensation mentioned in the provided policy documents.
# **Source**: Cancellation Policy – Hyperlocal

# %% [markdown]
# Case 2: Question Outside the Knowledge Base

# %%
question="What is Flipkart’s annual revenue?"
ans=chain2.invoke({"context":content_retrieval(question,1),"input": question})
print(ans.content)
# Out:
# **Answer**: I could not find this information in the provided policy documents.
# **Source**: Flipkart policy documents
